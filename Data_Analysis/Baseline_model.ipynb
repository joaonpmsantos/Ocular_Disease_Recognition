# %%
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
import pandas as pd
from PIL import Image
import os
import numpy as np

# %%
data = pd.read_csv("/Users/saravaz/code/joaonpmsantos/Ocular_Disease_Recognition/Data_Analysis/df_binary.csv")

# %%
data.head(20)
# Out:
#     Unnamed: 0  ID  Patient Age Patient Sex  Left-Fundus  Right-Fundus  \
# 0            0   0           69      Female   0_left.jpg   0_right.jpg
# 1            1   1           57        Male   1_left.jpg   1_right.jpg
# 2            2   2           42        Male   2_left.jpg   2_right.jpg
# 3            3   4           53        Male   4_left.jpg   4_right.jpg
# 4            4   5           50      Female   5_left.jpg   5_right.jpg
# 5            5   6           60        Male   6_left.jpg   6_right.jpg
# 6            6   7           60      Female   7_left.jpg   7_right.jpg
# 7            7   8           59        Male   8_left.jpg   8_right.jpg
# 8            8   9           54        Male   9_left.jpg   9_right.jpg
# 9            9  10           70        Male  10_left.jpg  10_right.jpg
# 10          10  11           60      Female  11_left.jpg  11_right.jpg
# 11          11  13           60      Female  13_left.jpg  13_right.jpg
# ...

# %%
image_folder = '/Users/saravaz/Downloads/Project_raw_data/preprocessed_images/'

# create an empty list to hold the image data
image_data = []

# iterate through each image file in the folder
for filename in os.listdir(image_folder):
    # open the image file
    img = Image.open(os.path.join(image_folder, filename))
    # convert the image to a numpy array
    img_array = np.array(img)
    # append the image array to the list
    image_data.append(img_array)

# %% [markdown]
# # Train/Test Split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=0)

# %% [markdown]
# # Normalization

# %%
X_train = X_train / 255
X_test = X_test / 255

# %% [markdown]
# # Optimizing K

# %%
K = np.arange(1, 26, 1)
scores = []

for k in K:
    model = KNeighborsClassifier(n_neighbors= k)
    cv_res = cross_val_score(model, X_train, y_train, cv=5)
    score = cv_res.mean()
    scores.append(score)
    
plt.plot(K, scores);
plt.ylabel('K value', fontsize = 14)
plt.xlabel('Score', fontsize = 14)
plt.title('Evolution of the score with K value', fontsize = 18, y = 1.03);

# %%
best_k = scores.index(max(scores)) + 1
best_k

# %%
base_model = KNeighborsClassifier()

cv_res = cross_val_score(base_model, X_train, y_train, cv= best_k)
base_knn_score = cv_res.mean()
base_knn_score
