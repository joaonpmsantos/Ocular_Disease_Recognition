# %%
import pandas as pd

# %%
df = pd.read_csv("/home/joaosantos/code/joaonpmsantos/Ocular_Disease_Recognition/raw_data/full_df.csv")

df.sample(20)
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 5207  2877           43      Female  2877_left.jpg  2877_right.jpg
# 5347  3028           51        Male  3028_left.jpg  3028_right.jpg
# 5163  2828           60        Male  2828_left.jpg  2828_right.jpg
# 12      14           55        Male    14_left.jpg    14_right.jpg
# 3135  4613           63        Male  4613_left.jpg  4613_right.jpg
# 6174  4425           33      Female  4425_left.jpg  4425_right.jpg
# 4963  2610           46      Female  2610_left.jpg  2610_right.jpg
# 1650  2480           63      Female  2480_left.jpg  2480_right.jpg
# 355    406           61      Female   406_left.jpg   406_right.jpg
# 2362  3251           66      Female  3251_left.jpg  3251_right.jpg
# 4623  2161           59        Male  2161_left.jpg  2161_right.jpg
# 5621  3329           44        Male  3329_left.jpg  3329_right.jpg
# 1808  2651           55      Female  2651_left.jpg  2651_right.jpg
# ...

# %%
df_right = df[["Right-Fundus", "Right-Diagnostic Keywords"]]
df_right
# Out:
#         Right-Fundus                          Right-Diagnostic Keywords
# 0        0_right.jpg                                      normal fundus
# 1        1_right.jpg                                      normal fundus
# 2        2_right.jpg             moderate non proliferative retinopathy
# 3        4_right.jpg                  mild nonproliferative retinopathy
# 4        5_right.jpg             moderate non proliferative retinopathy
# ...              ...                                                ...
# 6387  4686_right.jpg                 proliferative diabetic retinopathy
# 6388  4688_right.jpg             moderate non proliferative retinopathy
# 6389  4689_right.jpg                                      normal fundus
# 6390  4690_right.jpg                  mild nonproliferative retinopathy
# 6391  4784_right.jpg  hypertensive retinopathy，age-related macular d...
#
# [6392 rows x 2 columns]

# %%
df_left = df[["Left-Fundus", "Left-Diagnostic Keywords"]]
df_left.sample(20)
# Out:
#         Left-Fundus                           Left-Diagnostic Keywords
# 4911  2551_left.jpg                                      normal fundus
# 2223  3103_left.jpg                                      normal fundus
# 437    502_left.jpg                                             drusen
# 942   1129_left.jpg                              vitreous degeneration
# 5174  2839_left.jpg                                      normal fundus
# 1131  1441_left.jpg                                           glaucoma
# 1905  2763_left.jpg                                      normal fundus
# 5254  2929_left.jpg                                      normal fundus
# 5814  4028_left.jpg                  mild nonproliferative retinopathy
# 3872   778_left.jpg  myelinated nerve fibers，moderate non prolifera...
# 2666  4078_left.jpg                  mild nonproliferative retinopathy
# 4106  1075_left.jpg               wet age-related macular degeneration
# ...

# %%
df["Left-Diagnostic Keywords"].value_counts()
# Out:
# normal fundus                                              2796
# moderate non proliferative retinopathy                      717
# mild nonproliferative retinopathy                           428
# cataract                                                    268
# pathological myopia                                         208
#                                                            ...
# fundus laser photocoagulation spots                           1
# retinal pigment epithelium atrophy，diabetic retinopathy       1
# white vessel，suspected glaucoma                               1
# lens dust，glaucoma                                            1
# glaucoma，wet age-related macular degeneration                 1
# Name: Left-Diagnostic Keywords, Length: 196, dtype: int64

# %%
df["Right-Diagnostic Keywords"].value_counts()
# Out:
# normal fundus                                                                         2705
# moderate non proliferative retinopathy                                                 745
# mild nonproliferative retinopathy                                                      472
# cataract                                                                               250
# pathological myopia                                                                    216
#                                                                                       ...
# retinochoroidal coloboma，epiretinal membrane                                             1
# vitreous degeneration，lens dust                                                          1
# retinal pigment epithelial hypertrophy，moderate non proliferative retinopathy            1
# optic disc edema                                                                         1
# ...
