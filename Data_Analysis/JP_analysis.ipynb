# %%
import pandas as pd

# %% [markdown]
# # Creating a dataframe

# %%
df = pd.read_csv('/home/zenai/code/joaonpmsantos/Ocular_Disease_Recognition/raw_data/full_df.csv')

# %%
df
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 0        0           69      Female     0_left.jpg     0_right.jpg
# 1        1           57        Male     1_left.jpg     1_right.jpg
# 2        2           42        Male     2_left.jpg     2_right.jpg
# 3        4           53        Male     4_left.jpg     4_right.jpg
# 4        5           50      Female     5_left.jpg     5_right.jpg
# ...    ...          ...         ...            ...             ...
# 6387  4686           63        Male  4686_left.jpg  4686_right.jpg
# 6388  4688           42        Male  4688_left.jpg  4688_right.jpg
# 6389  4689           54        Male  4689_left.jpg  4689_right.jpg
# 6390  4690           57        Male  4690_left.jpg  4690_right.jpg
# 6391  4784           58        Male  4784_left.jpg  4784_right.jpg
#
#                                Left-Diagnostic Keywords  \
# 0                                              cataract
# ...

# %% [markdown]
# # HYPERTENSION

# %% [markdown]
# ## Selecting the rows with hypertension (column H == 1)

# %%
hypertension = df[df['H'] == 1]
hypertension
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 10      11           60      Female    11_left.jpg    11_right.jpg
# 19      23           47        Male    23_left.jpg    23_right.jpg
# 23      28           63      Female    28_left.jpg    28_right.jpg
# 26      32           64      Female    32_left.jpg    32_right.jpg
# 36      45           54        Male    45_left.jpg    45_right.jpg
# ...    ...          ...         ...            ...             ...
# 6302  4579           58        Male  4579_left.jpg  4579_right.jpg
# 6303  4581           43        Male  4581_left.jpg  4581_right.jpg
# 6313  4591           65        Male  4591_left.jpg  4591_right.jpg
# 6314  4592           58        Male  4592_left.jpg  4592_right.jpg
# 6391  4784           58        Male  4784_left.jpg  4784_right.jpg
#
#                                Left-Diagnostic Keywords  \
# 10    moderate non proliferative retinopathy，hyperte...
# ...

# %% [markdown]
# ## Checking if all rows with hypertension have a certain keyword ('hypertensive') in either left or right-eye diagnosis

# %%
selected_rows = (hypertension['Left-Diagnostic Keywords'].str.contains('hypertensive')) | (hypertension['Right-Diagnostic Keywords'].str.contains('hypertensive'))

# %% [markdown]
# ## Counting rows with the keyword 'hypertensive'

# %%
selected_rows
# Out:
# 10      True
# 19      True
# 23      True
# 26      True
# 36      True
#         ...
# 6302    True
# 6303    True
# 6313    True
# 6314    True
# 6391    True
# Length: 203, dtype: bool

# %%
selected_rows.sum()
# Out:
# 203

# %% [markdown]
# # MYOPIA

# %% [markdown]
# ## Selecting the rows with hypertension (column M == 1)

# %%
myopia = df[df['M'] == 1]
myopia
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 11      13           60      Female    13_left.jpg    13_right.jpg
# 14      16           54      Female    16_left.jpg    16_right.jpg
# 16      18           58        Male    18_left.jpg    18_right.jpg
# 29      35           68      Female    35_left.jpg    35_right.jpg
# 37      46           66        Male    46_left.jpg    46_right.jpg
# ...    ...          ...         ...            ...             ...
# 4474  1710           62        Male  1710_left.jpg  1710_right.jpg
# 4475  1716           66        Male  1716_left.jpg  1716_right.jpg
# 4476  1718           65        Male  1718_left.jpg  1718_right.jpg
# 4477  1731           72      Female  1731_left.jpg  1731_right.jpg
# 4533  1971           65        Male  1971_left.jpg  1971_right.jpg
#
#                                Left-Diagnostic Keywords  \
# 11                                  pathological myopia
# ...

# %% [markdown]
# ## Checking if all rows with myopia have a certain keyword ('myopia') in either left or right-eye diagnosis

# %%
selected_rows_2 = (myopia['Left-Diagnostic Keywords'].str.contains('myopia')) | (myopia['Right-Diagnostic Keywords'].str.contains('myopia'))
selected_rows_2
# Out:
# 11      True
# 14      True
# 16      True
# 29      True
# 37      True
#         ...
# 4474    True
# 4475    True
# 4476    True
# 4477    True
# 4533    True
# Length: 306, dtype: bool

# %%
selected_rows_2.sum()
# Out:
# 302

# %% [markdown]
# ## Identifying missing rows

# %%
false_elements = selected_rows_2.loc[~selected_rows_2]
false_elements
# Out:
# 333     False
# 1019    False
# 3525    False
# 4218    False
# dtype: bool

# %%
df.iloc[false_elements.index]
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 333    382           62      Female   382_left.jpg   382_right.jpg
# 1019  1250           54        Male  1250_left.jpg  1250_right.jpg
# 3525   382           62      Female   382_left.jpg   382_right.jpg
# 4218  1250           54        Male  1250_left.jpg  1250_right.jpg
#
#      Left-Diagnostic Keywords Right-Diagnostic Keywords  N  D  G  C  A  H  M  \
# 333        myopic maculopathy        myopic maculopathy  0  0  0  0  0  0  1
# 1019                 glaucoma        myopic maculopathy  0  0  1  0  0  0  1
# 3525       myopic maculopathy        myopic maculopathy  0  0  0  0  0  0  1
# 4218                 glaucoma        myopic maculopathy  0  0  1  0  0  0  1
#
#       O                                           filepath labels  \
# 333   0  ../input/ocular-disease-recognition-odir5k/ODI...  ['O']
# 1019  0  ../input/ocular-disease-recognition-odir5k/ODI...  ['O']
# ...

# %% [markdown]
# > 'myopic' is in all 4 rows >>> use both keywords ('myopia' and 'myiopic')

# %% [markdown]
# # AGE

# %% [markdown]
# ## Selecting the rows with age (column A == 1)

# %%
age = df[df['A'] == 1]
age
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 34      43           35        Male    43_left.jpg    43_right.jpg
# 39      48           69      Female    48_left.jpg    48_right.jpg
# 44      53           65      Female    53_left.jpg    53_right.jpg
# 46      55           62        Male    55_left.jpg    55_right.jpg
# 57      71           56      Female    71_left.jpg    71_right.jpg
# ...    ...          ...         ...            ...             ...
# 4560  2078           42      Female  2078_left.jpg  2078_right.jpg
# 5774  3979           54        Male  3979_left.jpg  3979_right.jpg
# 5850  4068           58        Male  4068_left.jpg  4068_right.jpg
# 6091  4330           57      Female  4330_left.jpg  4330_right.jpg
# 6391  4784           58        Male  4784_left.jpg  4784_right.jpg
#
#                                Left-Diagnostic Keywords  \
# 34                 wet age-related macular degeneration
# ...

# %% [markdown]
# ## Checking if all rows with age have a certain keyword ('age') in either left or right-eye diagnosis

# %%
selected_rows_3 = (age['Left-Diagnostic Keywords'].str.contains('age')) | (age['Right-Diagnostic Keywords'].str.contains('age'))
selected_rows_3
# Out:
# 34      True
# 39      True
# 44      True
# 46      True
# 57      True
#         ...
# 4560    True
# 5774    True
# 5850    True
# 6091    True
# 6391    True
# Length: 319, dtype: bool

# %%
selected_rows_3.sum()
# Out:
# 319

# %% [markdown]
# # OTHER

# %%
other = df[df['O'] == 1]
other
# Out:
#         ID  Patient Age Patient Sex    Left-Fundus    Right-Fundus  \
# 2        2           42        Male     2_left.jpg     2_right.jpg
# 3        4           53        Male     4_left.jpg     4_right.jpg
# 5        6           60        Male     6_left.jpg     6_right.jpg
# 6        7           60      Female     7_left.jpg     7_right.jpg
# 8        9           54        Male     9_left.jpg     9_right.jpg
# ...    ...          ...         ...            ...             ...
# 5984  4219           63        Male  4219_left.jpg  4219_right.jpg
# 6007  4243           56      Female  4243_left.jpg  4243_right.jpg
# 6276  4551           53        Male  4551_left.jpg  4551_right.jpg
# 6310  4588           64      Female  4588_left.jpg  4588_right.jpg
# 6372  4659           42        Male  4659_left.jpg  4659_right.jpg
#
#                                Left-Diagnostic Keywords  \
# 2     laser spot，moderate non proliferative retinopathy
# ...

# %%
selected_rows_4 = (other['Left-Diagnostic Keywords'].str.contains('drusen')) | (other['Right-Diagnostic Keywords'].str.contains('drusen'))
selected_rows_4
# Out:
# 2       False
# 3       False
# 5       False
# 6        True
# 8       False
#         ...
# 5984    False
# 6007    False
# 6276    False
# 6310    False
# 6372    False
# Length: 1588, dtype: bool

# %%
selected_rows_4.sum()
# Out:
# 236

# %%
cena = (df['Left-Diagnostic Keywords'].str.contains('drusen')) | (df['Right-Diagnostic Keywords'].str.contains('drusen'))
cena.sum()
# Out:
# 236
